# %%
# Use this cell to begin your analyses, and add as many cells as you would like!
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/lego-analysis/master/datasets/lego_sets.csv')
parent_theme = pd.read_csv('https://raw.githubusercontent.com/KeithGalli/lego-analysis/master/datasets/parent_themes.csv')

df.head(50)
# Out:
#     set_num                                           name  year  num_parts  \
# 0      00-1                                Weetabix Castle  1970      471.0
# 1    0011-2                              Town Mini-Figures  1978        NaN
# 2    0011-3                     Castle 2 for 1 Bonus Offer  1987        NaN
# 3    0012-1                             Space Mini-Figures  1979       12.0
# 4    0013-1                             Space Mini-Figures  1979       12.0
# 5    0014-1                             Space Mini-Figures  1979       12.0
# 6    0015-1                             Space Mini-Figures  1979        NaN
# 7    0016-1                            Castle Mini Figures  1978        NaN
# 8      00-2                   Weetabix Promotional House 1  1976        NaN
# 9      00-3                   Weetabix Promotional House 2  1976        NaN
# 10     00-4                  Weetabix Promotional Windmill  1976      126.0
# ...

# %%
df.head()
# Out:
#   set_num                        name  year  num_parts    theme_name  \
# 0    00-1             Weetabix Castle  1970      471.0        Castle
# 1  0011-2           Town Mini-Figures  1978        NaN  Supplemental
# 2  0011-3  Castle 2 for 1 Bonus Offer  1987        NaN  Lion Knights
# 3  0012-1          Space Mini-Figures  1979       12.0  Supplemental
# 4  0013-1          Space Mini-Figures  1979       12.0  Supplemental
#
#   parent_theme
# 0     Legoland
# 1         Town
# 2       Castle
# 3        Space
# 4        Space

# %%
#i think this is right?

# %%
parent_theme.head(50)
# Out:
#      id                      name  is_licensed
# 0     1                   Technic        False
# 1    22                   Creator        False
# 2    50                      Town        False
# 3   112                    Racers        False
# 4   126                     Space        False
# 5   147                   Pirates        False
# 6   155         Modular Buildings        False
# 7   158                 Star Wars         True
# 8   186                    Castle        False
# 9   204             Designer Sets        False
# 10  206                  Seasonal        False
# 11  233                     Train        False
# 12  246              Harry Potter         True
# 13  252              Architecture        False
# 14  254               Bulk Bricks        False
# 15  258                Mindstorms        False
# 16  263  Pirates of the Caribbean         True
# 17  264             Indiana Jones         True
# 18  269                      Cars         True
# ...

# %%
merged = df.merge(parent_theme, left_on='parent_theme', right_on='name')
merged.head()
# Out:
#   set_num                             name_x  year  num_parts theme_name  \
# 0    00-1                    Weetabix Castle  1970      471.0     Castle
# 1    00-2       Weetabix Promotional House 1  1976        NaN   Building
# 2    00-3       Weetabix Promotional House 2  1976        NaN   Building
# 3    00-4      Weetabix Promotional Windmill  1976      126.0   Building
# 4    00-7  Weetabix Promotional Lego Village  1976        NaN   Building
#
#   parent_theme   id    name_y  is_licensed
# 0     Legoland  411  Legoland        False
# 1     Legoland  411  Legoland        False
# 2     Legoland  411  Legoland        False
# 3     Legoland  411  Legoland        False
# 4     Legoland  411  Legoland        False

# %%
merged = df.merge(parent_theme, left_on='parent_theme', right_on='name')
merged.drop(columns='name_y', inplace=True)
merged.head()
# Out:
#   set_num                             name_x  year  num_parts theme_name  \
# 0    00-1                    Weetabix Castle  1970      471.0     Castle
# 1    00-2       Weetabix Promotional House 1  1976        NaN   Building
# 2    00-3       Weetabix Promotional House 2  1976        NaN   Building
# 3    00-4      Weetabix Promotional Windmill  1976      126.0   Building
# 4    00-7  Weetabix Promotional Lego Village  1976        NaN   Building
#
#   parent_theme   id  is_licensed
# 0     Legoland  411        False
# 1     Legoland  411        False
# 2     Legoland  411        False
# 3     Legoland  411        False
# 4     Legoland  411        False

# %%
licensed = merged[merged['is_licensed']]
licensed.head()

star_wars = licensed[licensed['parent_theme']=='Star Wars']

star_wars.head(50)
# Out:
#         set_num                                    name_x  year  num_parts  \
# 3493    10018-1                                Darth Maul  2001     1868.0
# 3494    10019-1               Rebel Blockade Runner - UCS  2001        NaN
# 3495    10026-1                   Naboo Starfighter - UCS  2002        NaN
# 3496    10030-1             Imperial Star Destroyer - UCS  2002     3115.0
# 3497    10123-1                                Cloud City  2003      707.0
# 3498    10129-1                   Rebel Snowspeeder - UCS  2003     1456.0
# 3499    10131-1                    TIE Fighter Collection  2004        NaN
# 3500    10134-1           Y-wing Attack Starfighter - UCS  2004        NaN
# 3501    10143-1                             Death Star II  2005        NaN
# 3502    10144-1                               Sandcrawler  2005     1679.0
# 3503    10174-1                      Imperial AT-ST - UCS  2006        NaN
# ...

# %%
licensed = merged[merged['is_licensed']]
licensed.head()

star_wars = licensed[licensed['parent_theme']=='Star Wars']

star_wars.shape
# Out:
# (609, 8)

# %%
# the reason we have an on 45 error is because we did not filter out all of our data properly. 
licensed = merged[merged['is_licensed']]
licensed.head()

star_wars = licensed[licensed['parent_theme']=='Star Wars']

the_force = int(star_wars.shape[0]/licensed.shape[0]*100)

print(the_force)
# Out:
# 45

# %%
#so it changes to 51, we got rid of the nna rows and let us get that percentage. 51 is the correct answer. 52 is also works. for the first task. 
licensed = merged[merged['is_licensed']]
licensed = licensed.dropna(subset=['set_num'])
licensed.head()

star_wars = licensed[licensed['parent_theme']=='Star Wars']

the_force = int(star_wars.shape[0]/licensed.shape[0]*100)

print(the_force)
# Out:
# 51

# %%
#starting with task 2, we want to find out the most important year. groupby method???

licensed.head()
# Out:
#       set_num                         name_x  year  num_parts  \
# 3493  10018-1                     Darth Maul  2001     1868.0
# 3494  10019-1    Rebel Blockade Runner - UCS  2001        NaN
# 3495  10026-1        Naboo Starfighter - UCS  2002        NaN
# 3496  10030-1  Imperial Star Destroyer - UCS  2002     3115.0
# 3497  10123-1                     Cloud City  2003      707.0
#
#                    theme_name parent_theme   id  is_licensed
# 3493                Star Wars    Star Wars  158         True
# 3494  Star Wars Episode 4/5/6    Star Wars  158         True
# 3495      Star Wars Episode 1    Star Wars  158         True
# 3496  Star Wars Episode 4/5/6    Star Wars  158         True
# 3497  Star Wars Episode 4/5/6    Star Wars  158         True

# %%
 # task 2 is completed, 
    licensed_sorted = licensed.sort_values('year')
licensed_sorted['count'] = 1

summed_df = licensed_sorted.groupby(['year', 'parent_theme']).sum().reset_index()

max_df = summed_df.sort_values('count', ascending=False).drop_duplicates(['year'])

max_df.sort_values('year', inplace=True)
max_df
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_13764\337565426.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   summed_df = licensed_sorted.groupby(['year', 'parent_theme']).sum().reset_index()
#     year  parent_theme  num_parts     id  is_licensed  count
# 0   1999     Star Wars     1384.0   2054           13     13
# 2   2000     Star Wars     2580.0   4108           26     26
# 4   2001     Star Wars     2949.0   2212           14     14
# 6   2002     Star Wars     4735.0   4424           28     28
# 9   2003     Star Wars     6660.0   5056           32     32
# 12  2004     Star Wars     1659.0   3160           20     20
# 16  2005     Star Wars     4730.0   4424           28     28
# 20  2006     Star Wars     2769.0   1738           11     11
# ...

# %%
new_era = 2017
#im not sure why is not working... ahhh nvm. when you are doing projects 
#in datacamp come up with your own task so you can really know the data thats in front of you.

# %% [markdown]
# # Break down number by Year.

# %%
#idk why is it not working its the same code as the youtuber. nvm it worked 
clean_df = merged[merged['set_num'].isnull()]
clean_df['count'] = 1 

sets_per_year = clean_df.groupby(['year']).sum().reset_index()[['year','count']]

sets_per_year.head (50)
# Out:
# C:\Users\Student\AppData\Local\Temp\ipykernel_13764\2902911714.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['count'] = 1
# C:\Users\Student\AppData\Local\Temp\ipykernel_13764\2902911714.py:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sets_per_year = clean_df.groupby(['year']).sum().reset_index()[['year','count']]
#     year  count
# 0   2001      3
# 1   2002      9
# 2   2003      3
# 3   2004      9
# 4   2005      2
# 5   2006      3
# 6   2007      2
# 7   2008      2
# 8   2010      4
# 9   2011      2
# 10  2012     10
# ...

# %%
clean_df = merged[merged['set_num'].isnull()]
clean_df['count'] = 1 

sets_per_year = clean_df.groupby(['year']).sum().reset_index()[['year','count']]

for index,row in sets_per_year.iterrows():
    print(row['year'],row['count'])
# Out:
# 2001 3
# 2002 9
# 2003 3
# 2004 9
# 2005 2
# 2006 3
# 2007 2
# 2008 2
# 2010 4
# 2011 2
# 2012 10
# 2013 15
# 2014 17
# 2015 10
# 2016 26
# 2017 36
# C:\Users\Student\AppData\Local\Temp\ipykernel_13764\536764443.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df['count'] = 1
# C:\Users\Student\AppData\Local\Temp\ipykernel_13764\536764443.py:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sets_per_year = clean_df.groupby(['year']).sum().reset_index()[['year','count']]
